# %%
#!pip install dtreeviz

# %%
import pandas as pd
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt
import dtreeviz
import graphviz
import graphviz.backend as be
from IPython.display import Image, display_svg, SVG
import warnings
warnings.filterwarnings( "ignore", module = "matplotlib\..*" )

# %%
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
import matplotlib.font_manager
fm = matplotlib.font_manager
fm._get_fontconfig_fonts.cache_clear()
plt.rcParams['font.family'] = 'Times New Roman'

# %% [markdown]
# ## Loading data

# %%
df= pd.read_csv('../data/cleaned/withyr_builtencoded.csv')
df
# Out:
#        sqft_above  sqft_lot15  sqft_living15          id  waterfront  view  \
# 0            1180        5650           1340  7129300520           0     0
# 1            2170        7639           1690  6414100192           0     0
# 2             770        8062           2720  5631500400           0     0
# 3            1050        5000           1360  2487200875           0     0
# 4            1680        7503           1800  1954400510           0     0
# ...           ...         ...            ...         ...         ...   ...
# 21592        1530        1509           1530   263000018           0     0
# 21593        2310        7200           1830  6600060120           0     0
# 21594        1020        2007           1020  1523300141           0     0
# 21595        1600        1287           1410   291310100           0     0
# 21596        1020        1357           1020  1523300157           0     0
#
#        condition  grade  bedrooms  sqft_basement_cat  floors  yr_built_cat  \
# 0              3      7         3                  1     1.0             1
# 1              3      7         3                  2     2.0             1
# 2              3      6         2                  1     1.0             1
# 3              5      7         4                  3     1.0             1
# 4              3      8         3                  1     1.0             1
# ...          ...    ...       ...                ...     ...           ...
# 21592          3      8         3                  1     3.0             2
# 21593          3      8         4                  1     2.0             3
# 21594          3      7         2                  1     2.0             2
# 21595          3      8         3                  1     2.0             2
# 21596          3      7         2                  1     2.0             2
#
#        zip        id.1   price
# 0        1  7129300520  221900
# 1        1  6414100192  538000
# 2        0  5631500400  180000
# 3        1  2487200875  604000
# 4        0  1954400510  510000
# ...    ...         ...     ...
# 21592    1   263000018  360000
# 21593    1  6600060120  400000
# 21594    1  1523300141  402101
# 21595    0   291310100  400000
# 21596    1  1523300157  325000
#
# [21597 rows x 15 columns]

# %%
#select properties above 650k
df = df[df['price'] > 650000]
df.shape
# Out:
# (5205, 15)

# %%
#divide x and y
X = df.drop(columns=["price","id","id.1"])
y = df["price"]

# %%
X.columns
# Out:
# Index(['sqft_above', 'sqft_lot15', 'sqft_living15', 'waterfront', 'view',
#        'condition', 'grade', 'bedrooms', 'sqft_basement_cat', 'floors',
#        'yr_built_cat', 'zip'],
#       dtype='object')

# %% [markdown]
# we will power transform our X dataset

# %%
from sklearn.preprocessing import PowerTransformer
pt= PowerTransformer()
pt.fit(X)
# Out:
# PowerTransformer()

# %%
X_transformed= pt.transform(X)
X= pd.DataFrame(X_transformed, columns=X.columns)

# %%
X.describe().T
# Out:
#                     count          mean       std        min       25%  \
# sqft_above         5205.0  5.515068e-16  1.000096  -3.288107 -0.770637
# sqft_lot15         5205.0 -8.343587e-15  1.000096  -4.292241 -0.670695
# sqft_living15      5205.0 -1.159325e-15  1.000096  -3.072324 -0.734280
# waterfront         5205.0 -1.638139e-17  1.000096  -0.161933 -0.161933
# view               5205.0  1.501627e-17  1.000096  -0.575726 -0.575726
# condition          5205.0  4.903496e-15  1.000096 -13.899405 -0.668491
# grade              5205.0 -3.549301e-16  1.000096  -3.888235 -0.685052
# bedrooms           5205.0  4.463928e-16  1.000096  -4.161104 -0.937880
# sqft_basement_cat  5205.0 -2.163708e-16  1.000096  -0.956503 -0.956503
# floors             5205.0  6.006509e-17  1.000096  -1.430988 -1.430988
# yr_built_cat       5205.0  4.586789e-15  1.000096  -0.733526 -0.733526
# zip                5205.0 -3.822324e-17  1.000096  -0.803162 -0.803162
#
#                         50%       75%       max
# sqft_above         0.062329  0.743088  3.949487
# sqft_lot15        -0.000500  0.538551  3.056485
# sqft_living15      0.048111  0.720165  3.386583
# waterfront        -0.161933 -0.161933  6.175382
# view              -0.575726 -0.575726  1.811154
# condition         -0.668491  0.966874  1.865529
# grade              0.163088  0.936020  2.916187
# bedrooms           0.253241  0.253241  5.174165
# sqft_basement_cat -0.956503  0.908767  1.322945
# floors             0.559129  0.559129  3.922182
# yr_built_cat      -0.733526  1.289585  1.615897
# zip               -0.803162  1.245079  1.245079

# %% [markdown]
# standard normalization to my dataset  to bound them between [0,1] or [1,-1]

# %%
from sklearn.preprocessing import minmax_scale
X_scaled= minmax_scale(X)
X= pd.DataFrame(X_scaled, columns=X.columns)
X.describe().T
# Out:
#                     count      mean       std  min       25%       50%  \
# sqft_above         5205.0  0.454309  0.138181  0.0  0.347833  0.462921
# sqft_lot15         5205.0  0.584080  0.136091  0.0  0.492813  0.584012
# sqft_living15      5205.0  0.475672  0.154840  0.0  0.361988  0.483121
# waterfront         5205.0  0.025552  0.157811  0.0  0.000000  0.000000
# view               5205.0  0.241204  0.418997  0.0  0.000000  0.000000
# condition          5205.0  0.881666  0.063438  0.0  0.839262  0.839262
# grade              5205.0  0.571428  0.146977  0.0  0.470750  0.595396
# bedrooms           5205.0  0.445740  0.107131  0.0  0.345274  0.472867
# sqft_basement_cat  5205.0  0.419620  0.438745  0.0  0.000000  0.000000
# floors             5205.0  0.267316  0.186823  0.0  0.000000  0.371764
# yr_built_cat       5205.0  0.312215  0.425677  0.0  0.000000  0.000000
# zip                5205.0  0.392123  0.488271  0.0  0.000000  0.000000
#
#                         75%  max
# sqft_above         0.556980  1.0
# sqft_lot15         0.657364  1.0
# sqft_living15      0.587172  1.0
# waterfront         0.000000  1.0
# view               0.000000  1.0
# condition          0.942997  1.0
# grade              0.708988  1.0
# bedrooms           0.472867  1.0
# sqft_basement_cat  0.818299  1.0
# floors             0.371764  1.0
# yr_built_cat       0.861110  1.0
# zip                1.000000  1.0

# %%
X.describe().T
# Out:
#                     count      mean       std  min       25%       50%  \
# sqft_above         5205.0  0.454309  0.138181  0.0  0.347833  0.462921
# sqft_lot15         5205.0  0.584080  0.136091  0.0  0.492813  0.584012
# sqft_living15      5205.0  0.475672  0.154840  0.0  0.361988  0.483121
# waterfront         5205.0  0.025552  0.157811  0.0  0.000000  0.000000
# view               5205.0  0.241204  0.418997  0.0  0.000000  0.000000
# condition          5205.0  0.881666  0.063438  0.0  0.839262  0.839262
# grade              5205.0  0.571428  0.146977  0.0  0.470750  0.595396
# bedrooms           5205.0  0.445740  0.107131  0.0  0.345274  0.472867
# sqft_basement_cat  5205.0  0.419620  0.438745  0.0  0.000000  0.000000
# floors             5205.0  0.267316  0.186823  0.0  0.000000  0.371764
# yr_built_cat       5205.0  0.312215  0.425677  0.0  0.000000  0.000000
# zip                5205.0  0.392123  0.488271  0.0  0.000000  0.000000
#
#                         75%  max
# sqft_above         0.556980  1.0
# sqft_lot15         0.657364  1.0
# sqft_living15      0.587172  1.0
# waterfront         0.000000  1.0
# view               0.000000  1.0
# condition          0.942997  1.0
# grade              0.708988  1.0
# bedrooms           0.472867  1.0
# sqft_basement_cat  0.818299  1.0
# floors             0.371764  1.0
# yr_built_cat       0.861110  1.0
# zip                1.000000  1.0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state = 1)

# We need to cast again into df to visualize the decision tree
X_train_df = pd.DataFrame(X_train, columns=X.columns)
#y_train_df = pd.DataFrame(y_train, columns=["Price"])

X_test_df = pd.DataFrame(X_test, columns=X.columns)
#y_test_df = pd.DataFrame(y_test, columns=["Price"])

# %%
X_train_df
# Out:
#       sqft_above  sqft_lot15  sqft_living15  waterfront  view  condition  \
# 4541    0.398429    0.688961       0.475111         0.0   0.0   0.839262
# 3842    0.427966    0.496771       0.590641         0.0   0.0   1.000000
# 1457    0.543852    0.516421       0.588908         0.0   0.0   0.839262
# 460     0.355455    0.610751       0.454695         0.0   0.0   0.942997
# 2418    0.296614    0.616801       0.471073         0.0   0.0   0.942997
# ...          ...         ...            ...         ...   ...        ...
# 905     0.345904    0.610576       0.369030         0.0   0.0   0.839262
# 5192    0.690491    0.583260       0.531331         0.0   0.0   0.839262
# 3980    0.389839    0.543528       0.467012         0.0   1.0   0.839262
# 235     0.237757    0.522787       0.211772         0.0   0.0   0.839262
# 5157    0.381066    0.134885       0.420788         0.0   0.0   0.839262
#
#          grade  bedrooms  sqft_basement_cat    floors  yr_built_cat  zip
# 4541  0.708988  0.345274           1.000000  0.000000       0.86111  0.0
# 3842  0.708988  0.345274           0.818299  0.371764       0.00000  1.0
# 1457  0.595396  0.472867           0.000000  0.371764       0.86111  0.0
# 460   0.470750  0.472867           1.000000  0.000000       0.00000  0.0
# 2418  0.470750  0.345274           0.818299  0.000000       0.00000  0.0
# ...        ...       ...                ...       ...           ...  ...
# 905   0.470750  0.345274           0.531680  0.000000       0.00000  0.0
# 5192  0.708988  0.583755           0.000000  0.371764       0.86111  0.0
# 3980  0.595396  0.193075           0.000000  0.371764       0.00000  0.0
# 235   0.332550  0.345274           0.531680  0.000000       0.00000  1.0
# 5157  0.470750  0.345274           0.531680  0.572789       1.00000  0.0
#
# [3903 rows x 12 columns]

# %% [markdown]
# we will fit a decision tree, we will use a crossvalidation to explore the best fitting model

# %%
regr = DecisionTreeRegressor(max_depth=5,
                             criterion = 'squared_error',
                             min_samples_split=2,
                             min_samples_leaf = 1,
                             max_features = 6)

# %%
from sklearn.model_selection import cross_validate


results = cross_validate(regr, X_train, y_train, cv = 5)
results
# Out:
# {'fit_time': array([0.0109942 , 0.00999475, 0.00899458, 0.01299238, 0.01299334]),
#  'score_time': array([0.00299811, 0.00399733, 0.00299835, 0.00199914, 0.00399709]),
#  'test_score': array([0.39250015, 0.304464  , 0.48109107, 0.46309949, 0.54214758])}

# %%
#get average of testscore
print(results['test_score'])
print("The average R2 over the folds is: {:.2f}".format(results['test_score'].mean()))
# Out:
# [0.39250015 0.304464   0.48109107 0.46309949 0.54214758]
# The average R2 over the folds is: 0.44

# %% [markdown]
# R2 score is very low

# %% [markdown]
# let´s use grid search to find a better performance

# %%
from sklearn.model_selection import GridSearchCV

max_depth_choices = [3,5] # max_depth lists to try
criterion_choices = ['squared_error','absolute_error'] # possible values optimization metrics list
min_samples_split_choices = [2,10] # list of possible values of min_samples_split to try
min_samples_leaf_choices = [2,10] # list of the possible values of min_samples_leaf to try

# %%
#create grid, which is a dictionary with hyperparameters
grid = {'max_depth': max_depth_choices,
        'criterion': criterion_choices,
        'min_samples_split': min_samples_split_choices,
        'min_samples_leaf': min_samples_leaf_choices}

# %%
model = DecisionTreeRegressor()
grid_search = GridSearchCV(estimator = model, param_grid = grid, cv = 5)

# %%
#fit
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_depth': [3, 5], 'min_samples_leaf': [2, 10],
#                          'min_samples_split': [2, 10]})

# %%
#best r2
print("The best R2 for the best hyperparameters is {:.2f}".format(grid_search.best_score_))
# Out:
# The best R2 for the best hyperparameters is 0.44

# %%
#see the best parameter
grid_search.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 5,
#  'min_samples_leaf': 10,
#  'min_samples_split': 2}

# %% [markdown]
# check random search

# %%
import numpy as np

# %%
from sklearn.model_selection import RandomizedSearchCV

max_depth_choices= np.random.randint(low=1, high=len(X.columns), size=3) # A random integer between 1 and the number of columns
criterion_choices =  ['squared_error','absolute_error'] # A list of the possible values optimization metrics
min_samples_split_choices = np.random.randint(low=2, high=10, size=3) # A random integer between 1 and the number of columns
min_samples_leaf_choices = np.random.randint(low=2, high=10, size=3) # A random integer between 1 and the number of columns
max_features_choices = np.random.randint(low=1, high=len(X.columns), size=3) # A random integer between 1 and the number of columns

random_grid = {'max_depth': max_depth_choices,
               'criterion': criterion_choices,
               'min_samples_split': min_samples_split_choices,
               'min_samples_leaf': min_samples_leaf_choices,
               'max_features': max_features_choices}

# %%
model = DecisionTreeRegressor()
# n_iter is how many random combinations of hyperparameters will test use the computer.
random_search = RandomizedSearchCV(estimator = model, param_distributions = random_grid, n_iter=25, cv = 5, n_jobs = 2)

# %%
random_search.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(), n_iter=25, n_jobs=2,
#                    param_distributions={'criterion': ['squared_error',
#                                                       'absolute_error'],
#                                         'max_depth': array([1, 5, 6]),
#                                         'max_features': array([11,  9,  1]),
#                                         'min_samples_leaf': array([8, 3, 9]),
#                                         'min_samples_split': array([5, 5, 5])})

# %%
random_search.best_params_
# Out:
# {'min_samples_split': 5,
#  'min_samples_leaf': 9,
#  'max_features': 9,
#  'max_depth': 5,
#  'criterion': 'squared_error'}

# %%
print("The best R2 according to the random search is {:.2f}".format(random_search.best_score_))
# Out:
# The best R2 according to the random search is 0.47

# %%
#let´s use this model
model = DecisionTreeRegressor (min_samples_split= 10,
                               min_samples_leaf= 8,
                               max_features= 8,
                               max_depth= 9,
                               criterion= 'squared_error')

# %%
model.fit(X_train, y_train)
model.score(X_test, y_test).round(2)
# Out:
# 0.39

# %% [markdown]
# so far it had produced the best R2 score at 0.63 for the test data, a litle above the score from randomized search . and for train set
# :

# %%
model.score(X_train, y_train).round(2)
# Out:
# 0.67

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
y_train_pred = [round(value, 2) for value in y_train_pred]
y_test_pred= [round(value, 2) for value in y_test_pred]

# Create a dictionary with the results
results = {
    "Set": ["Train"] * len(X_train) + ["Test"] * len(X_test),
    "Real": list(y_train) + list(y_test),
    "Predicted": y_train_pred + y_test_pred
}

# Create the results DataFrame
results_df = pd.DataFrame(results)
results_df
# Out:
#         Set     Real   Predicted
# 0     Train   680000  1045122.12
# 1     Train  1600000  1264375.00
# 2     Train   731000   796917.84
# 3     Train   962000   747161.46
# 4     Train   714000   763507.68
# ...     ...      ...         ...
# 5200   Test  1140000  1014868.50
# 5201   Test   818500   962461.57
# 5202   Test   725000  1014868.50
# 5203   Test   680000   693539.78
# 5204   Test   872000   941824.58
#
# [5205 rows x 3 columns]

# %%
results_df.columns
# Out:
# Index(['Set', 'Real', 'Predicted'], dtype='object')

# %% [markdown]
# ## feature importance
# we will consider the order of importance of our features

# %%
#check feature importance
importances = model.feature_importances_
importances
# Out:
# array([0.0795167 , 0.03895677, 0.09134113, 0.13960371, 0.02964995,
#        0.0054514 , 0.45487647, 0.03111525, 0.07557649, 0.00112114,
#        0.00281428, 0.04997672])

# %%
#get the feature importance in a dataframe
feature_importance = pd.DataFrame({"feature": X.columns, "importance": importances})

# %%
#feature importance
feature_importance.sort_values(by="importance", ascending=False).reset_index(drop=True)
# Out:
#               feature  importance
# 0               grade    0.454876
# 1          waterfront    0.139604
# 2       sqft_living15    0.091341
# 3          sqft_above    0.079517
# 4   sqft_basement_cat    0.075576
# 5                 zip    0.049977
# 6          sqft_lot15    0.038957
# 7            bedrooms    0.031115
# 8                view    0.029650
# 9           condition    0.005451
# 10       yr_built_cat    0.002814
# 11             floors    0.001121

# %%
#export feature importance
feature_importance.to_csv('../data/cleaned/feature_importance.csv', index=False)

# %%
results_df['Errors'] = results_df['Real'] - results_df['Predicted']
results_df.head()
# Out:
#      Set     Real   Predicted     Errors
# 0  Train   680000  1045122.12 -365122.12
# 1  Train  1600000  1264375.00  335625.00
# 2  Train   731000   796917.84  -65917.84
# 3  Train   962000   747161.46  214838.54
# 4  Train   714000   763507.68  -49507.68

# %%
#select only rows where real is greater than 1000000
results_df2 = results_df[results_df['Real'] > 1000000]
results_df2.head()
# Out:
#       Set     Real   Predicted     Errors
# 1   Train  1600000  1264375.00  335625.00
# 10  Train  1280000  1101833.33  178166.67
# 16  Train  1800000  1288750.00  511250.00
# 19  Train  1300000   936025.00  363975.00
# 21  Train  1250000  1264375.00  -14375.00

# %%
#visualize real and predicted
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

fig, ax = plt.subplots(1,2, figsize=(10,5))

sns.scatterplot(data=results_df, x="Real", y="Predicted", hue="Set", ax=ax[0])
sns.lineplot(data=results_df, x="Real", y="Real", color="black", ax=ax[0])
ax[0].set_title("Predicted vs real")
sns.histplot(results_df, x="Errors", bins=50, hue="Set", ax=ax[1])
ax[1].set_title("Histogram of residuals")

plt.tight_layout()
plt.show()

# %%
#test for mae, mse, rmse, r2
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
def error_metrics_report(y_real_train: list, y_real_test: list, y_pred_train: list, y_pred_test: list) -> pd.DataFrame:
    '''
   The error metrics report function calculates for regression.

    Parameters:
    - y_real_train (list): The actual target values for the training dataset.
    - y_real_test (list): The actual target values for the testing dataset.
    - y_pred_train (list): The predicted target values for the training dataset.
    - y_pred_test (list): The predicted target values for the testing dataset.

    Returns:
    - metrics_df (DataFrame): A Pandas DataFrame containing error metrics for both the training and testing datasets.
    - 'Metric' (str): The name of the error metric.
    - 'Training Set' (float): The error metric value for the training set.
    - 'Testing Set' (float): The error metric value for the testing set.
    '''

    MAE_train = mean_absolute_error(y_real_train, y_pred_train)
    MAE_test  = mean_absolute_error(y_real_test, y_pred_test)

    # Mean squared error
    MSE_train = mean_squared_error(y_real_train, y_pred_train)
    MSE_test  = mean_squared_error(y_real_test, y_pred_test)

    # Root mean squared error
    RMSE_train = mean_squared_error(y_real_train, y_pred_train)
    RMSE_test  = mean_squared_error(y_real_test, y_pred_test)

    # R2
    R2_train = r2_score(y_real_train, y_pred_train)
    R2_test  = r2_score(y_real_test, y_pred_test)

    results = {"Metric":['MAE', 'MSE', 'RMSE', 'R2'] , 
               "Train": [MAE_train, MSE_train, RMSE_train, R2_train],
               "Test":  [MAE_test, MSE_test, RMSE_test, R2_test]}

    results_df = pd.DataFrame(results).round(2)

    pd.set_option('display.float_format', lambda x: '{:.2f}'.format(x))


    return results_df

# %%
error_metrics_report(list(results_df[results_df["Set"]=="Train"]["Real"]),
                     list(results_df[results_df["Set"]=="Test"]["Real"]),
                     list(results_df[results_df["Set"]=="Train"]["Predicted"]),
                     list(results_df[results_df["Set"]=="Test"]["Predicted"]))
# Out:
#   Metric          Train            Test
# 0    MAE      165848.82       207972.43
# 1    MSE 75633712173.09 138925442293.79
# 2   RMSE 75633712173.09 138925442293.79
# 3     R2           0.67            0.39
