# %% [markdown]
# ## Data transform 2
#
# For this, we will create a dataset where we will retain all outliers but focus on correcting skewers

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read in the data
num_df = pd.read_csv('../data/raw/numerical.csv')

display(num_df)
# Out:
#        bedrooms  bathrooms  sqft_above  floors  sqft_lot15  sqft_living15  \
# 0             3       1.00        1180     1.0        5650           1340
# 1             3       2.25        2170     2.0        7639           1690
# 2             2       1.00         770     1.0        8062           2720
# 3             4       3.00        1050     1.0        5000           1360
# 4             3       2.00        1680     1.0        7503           1800
# ...         ...        ...         ...     ...         ...            ...
# 21592         3       2.50        1530     3.0        1509           1530
# 21593         4       2.50        2310     2.0        7200           1830
# 21594         2       0.75        1020     2.0        2007           1020
# 21595         3       2.50        1600     2.0        1287           1410
# 21596         2       0.75        1020     2.0        1357           1020
#
#        sqft_basement
# 0                  0
# 1                400
# 2                  0
# 3                910
# 4                  0
# ...              ...
# 21592              0
# 21593              0
# 21594              0
# 21595              0
# 21596              0
#
# [21597 rows x 7 columns]

# %%
columns_to_plot = ["sqft_living15", "sqft_lot15", "sqft_above", "floors", "bedrooms", "bathrooms", "sqft_basement"]

fig, axes = plt.subplots(3, 3, figsize=(15, 15))
fig.suptitle('Distribution of numerical variables', fontsize=20)


for i, column in enumerate(columns_to_plot):
    row = i // 3
    col = i % 3
    sns.histplot(data=num_df, x=column, ax=axes[row, col])

# clear the extra subplots
for i in range(len(columns_to_plot), 3 * 3):
    row = i // 3
    col = i % 3
    fig.delaxes(axes[row, col])

plt.tight_layout()
plt.show()

# %%
#see skewness
print(num_df.skew())
# Out:
# bedrooms         2.023641
# bathrooms        0.519709
# sqft_above       1.447434
# floors           0.614497
# sqft_lot15       9.524362
# sqft_living15    1.106875
# sqft_basement    1.576890
# dtype: float64

# %% [markdown]
# we will apply power tranformation on columns with value above 1

# %%
#get get saved powertransformer
import pickle
with open('../transformers/pt.pkl', 'rb') as file:
    pt = pickle.load(file)
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator PowerTransformer from version 1.3.1 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
from sklearn.preprocessing import PowerTransformer

# %%
#select columns to transform if skewness is greater than 0.5 or less than -0.5
columns_to_transform = ["sqft_living15", "sqft_lot15", "sqft_above", "floors", "bedrooms", "bathrooms", "sqft_basement"]

# %%
data_to_transform = num_df[columns_to_transform]

# %%
#transform data
num_transform_df =pt.transform(data_to_transform)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 #transform data
# ----> 2 num_transform_df =pt.transform(data_to_transform)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:3204, in PowerTransformer.transform(self, X)
#    3191 """Apply the power transform to each feature using the fitted lambdas.
#    3192
#    3193 Parameters
#    (...)
#    3201     The transformed data.
#    3202 """
#    3203 check_is_fitted(self)
# -> 3204 X = self._check_input(X, in_fit=False, check_positive=True, check_shape=True)
#    3206 transform_function = {
#    3207     "box-cox": boxcox,
#    3208     "yeo-johnson": self._yeo_johnson_transform,
#    3209 }[self.method]
#    3210 for i, lmbda in enumerate(self.lambdas_):
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:3385, in PowerTransformer._check_input(self, X, in_fit, check_positive, check_shape)
#    3367 def _check_input(self, X, in_fit, check_positive=False, check_shape=False):
#    3368     """Validate the input before fit and transform.
#    3369
#    3370     Parameters
#    (...)
#    3383         If True, check that n_features matches the length of self.lambdas_
#    3384     """
# -> 3385     X = self._validate_data(
#    3386         X,
#    3387         ensure_2d=True,
#    3388         dtype=FLOAT_DTYPES,
#    3389         copy=self.copy,
#    3390         force_all_finite="allow-nan",
#    3391         reset=in_fit,
#    3392     )
#    3394     with warnings.catch_warnings():
#    3395         warnings.filterwarnings("ignore", r"All-NaN (slice|axis) encountered")
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:579, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     508 def _validate_data(
#     509     self,
#     510     X="no_validation",
#    (...)
#     515     **check_params,
#     516 ):
#     517     """Validate input data and set or check the `n_features_in_` attribute.
#     518
#     519     Parameters
#    (...)
#     577         validated.
#     578     """
# --> 579     self._check_feature_names(X, reset=reset)
#     581     if y is None and self._get_tags()["requires_y"]:
#     582         raise ValueError(
#     583             f"This {self.__class__.__name__} estimator "
#     584             "requires y to be passed, but the target y is None."
#     585         )
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:506, in BaseEstimator._check_feature_names(self, X, reset)
#     501 if not missing_names and not unexpected_names:
#     502     message += (
#     503         "Feature names must be in the same order as they were in fit.\n"
#     504     )
# --> 506 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - bathrooms
# - bedrooms
# - floors
# - sqft_basement
