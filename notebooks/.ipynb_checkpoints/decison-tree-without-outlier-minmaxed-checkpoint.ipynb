# %%
#!pip install dtreeviz

# %%
import pandas as pd
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt
import dtreeviz
import graphviz
import graphviz.backend as be
from IPython.display import Image, display_svg, SVG
import warnings
warnings.filterwarnings( "ignore", module = "matplotlib\..*" )

# %%
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
import matplotlib.font_manager
fm = matplotlib.font_manager
fm._get_fontconfig_fonts.cache_clear()
plt.rcParams['font.family'] = 'Times New Roman'

# %% [markdown]
# ## Loading data

# %%
df= pd.read_csv('../data/cleaned/data_without_outlier.csv')
df
# Out:
#        sqft_above  sqft_lot15  sqft_living15  waterfront  view  condition  \
# 0          1180.0      5650.0         1340.0           0     0          3
# 1          2170.0      7639.0         1690.0           0     0          3
# 2           770.0      8062.0         2720.0           0     0          3
# 3          1050.0      5000.0         1360.0           0     0          5
# 4          1680.0      7503.0         1800.0           0     0          3
# ...           ...         ...            ...         ...   ...        ...
# 18853      1530.0      1509.0         1530.0           0     0          3
# 18854      2310.0      7200.0         1830.0           0     0          4
# 18855      1020.0      2007.0         1020.0           0     0          3
# 18856      1600.0      1287.0         1410.0           0     0          3
# 18857      1020.0      1357.0         1020.0           0     0          4
#
#        grade  bedrooms  bathrooms  sqft_basement_cat  floors  yr_built_cat  \
# 0          7         3       1.00                  1     1.0             1
# 1          7         3       2.25                  2     2.0             1
# 2          6         2       1.00                  1     1.0             1
# 3          7         4       3.00                  3     1.0             1
# 4          8         3       2.00                  1     1.0             1
# ...      ...       ...        ...                ...     ...           ...
# 18853     10         6       3.25                  1     2.0             1
# 18854      7         2       1.00                  2     1.0             1
# 18855     10         3       2.50                  1     2.0             1
# 18856      7         3       1.00                  1     1.0             1
# 18857      7         4       2.25                  1     2.0             1
#
#        zip   price
# 0        1  221900
# 1        1  538000
# 2        0  180000
# 3        1  604000
# 4        0  510000
# ...    ...     ...
# 18853    0  925850
# 18854    0  255500
# 18855    0  450000
# 18856    0  280000
# 18857    0  245000
#
# [18858 rows x 14 columns]

# %%
#divide x and y
X = df.drop(columns=["price", 'bathrooms'])
y = df["price"]

# %%
X.columns
# Out:
# Index(['sqft_above', 'sqft_lot15', 'sqft_living15', 'waterfront', 'view',
#        'condition', 'grade', 'bedrooms', 'sqft_basement_cat', 'floors',
#        'yr_built_cat', 'zip'],
#       dtype='object')

# %% [markdown]
# we will power transform our X dataset

# %%
from sklearn.preprocessing import PowerTransformer
pt= PowerTransformer()
pt.fit(X)
# Out:
# PowerTransformer()

# %%
X_transformed= pt.transform(X)
X= pd.DataFrame(X_transformed, columns=X.columns)

# %%
X.describe().T
# Out:
#                      count          mean       std       min       25%  \
# sqft_above         18858.0 -6.366174e-15  1.000027 -4.015856 -0.709945
# sqft_lot15         18858.0  1.085143e-16  1.000027 -2.538477 -0.628046
# sqft_living15      18858.0  2.224544e-15  1.000027 -3.736080 -0.706640
# waterfront         18858.0 -2.675179e-17  1.000027 -0.090143 -0.090143
# view               18858.0 -7.742949e-17  1.000027 -0.337462 -0.337462
# condition          18858.0 -3.048197e-16  1.000027 -7.353062 -0.645962
# grade              18858.0 -2.071851e-15  1.000027 -7.324812 -0.445908
# bedrooms           18858.0 -6.360145e-16  1.000027 -3.279428 -0.337899
# sqft_basement_cat  18858.0  6.386520e-16  1.000027 -0.803236 -0.803236
# floors             18858.0  3.701167e-15  1.000027 -0.902006 -0.902006
# yr_built_cat       18858.0  2.009748e-12  1.000027 -0.493893 -0.493893
# zip                18858.0 -2.840965e-16  1.000027 -0.842713 -0.842713
#
#                         50%       75%        max
# sqft_above        -0.048269  0.740069   2.207879
# sqft_lot15         0.092517  0.624899   2.811962
# sqft_living15     -0.027081  0.715845   2.351850
# waterfront        -0.090143 -0.090143  11.093502
# view              -0.337462 -0.337462   2.965161
# condition         -0.645962  0.907561   2.008696
# grade             -0.445908  0.454471   3.298482
# bedrooms          -0.337899  0.738797  13.417187
# sqft_basement_cat -0.803236  1.290010   1.515746
# floors            -0.902006  1.172709   1.976135
# yr_built_cat      -0.493893 -0.493893   2.045577
# zip               -0.842713  1.186643   1.186643

# %% [markdown]
# standard normalization to my dataset  to bound them between [0,1] or [1,-1]

# %%
from sklearn.preprocessing import minmax_scale
X_scaled= minmax_scale(X)
X= pd.DataFrame(X_scaled, columns=X.columns)
X.describe().T
# Out:
#                      count      mean       std  min       25%       50%  \
# sqft_above         18858.0  0.645248  0.160679  0.0  0.531178  0.637493
# sqft_lot15         18858.0  0.474443  0.186906  0.0  0.357061  0.491734
# sqft_living15      18858.0  0.613686  0.164264  0.0  0.497614  0.609238
# waterfront         18858.0  0.008060  0.089419  0.0  0.000000  0.000000
# view               18858.0  0.102180  0.302798  0.0  0.000000  0.000000
# condition          18858.0  0.785436  0.106820  0.0  0.716436  0.716436
# grade              18858.0  0.689505  0.094135  0.0  0.647530  0.647530
# bedrooms           18858.0  0.196413  0.059894  0.0  0.176175  0.176175
# sqft_basement_cat  18858.0  0.346374  0.431235  0.0  0.000000  0.000000
# floors             18858.0  0.313399  0.347456  0.0  0.000000  0.000000
# yr_built_cat       18858.0  0.194487  0.393793  0.0  0.000000  0.000000
# zip                18858.0  0.415261  0.492780  0.0  0.000000  0.000000
#
#                         75%  max
# sqft_above         0.764159  1.0
# sqft_lot15         0.591237  1.0
# sqft_living15      0.731271  1.0
# waterfront         0.000000  1.0
# view               0.000000  1.0
# condition          0.882380  1.0
# grade              0.732285  1.0
# bedrooms           0.240661  1.0
# sqft_basement_cat  0.902657  1.0
# floors             0.720852  1.0
# yr_built_cat       0.000000  1.0
# zip                1.000000  1.0

# %%
X.describe().T
# Out:
#                      count      mean       std  min       25%       50%  \
# sqft_above         18858.0  0.645248  0.160679  0.0  0.531178  0.637493
# sqft_lot15         18858.0  0.474443  0.186906  0.0  0.357061  0.491734
# sqft_living15      18858.0  0.613686  0.164264  0.0  0.497614  0.609238
# waterfront         18858.0  0.008060  0.089419  0.0  0.000000  0.000000
# view               18858.0  0.102180  0.302798  0.0  0.000000  0.000000
# condition          18858.0  0.785436  0.106820  0.0  0.716436  0.716436
# grade              18858.0  0.689505  0.094135  0.0  0.647530  0.647530
# bedrooms           18858.0  0.196413  0.059894  0.0  0.176175  0.176175
# sqft_basement_cat  18858.0  0.346374  0.431235  0.0  0.000000  0.000000
# floors             18858.0  0.313399  0.347456  0.0  0.000000  0.000000
# yr_built_cat       18858.0  0.194487  0.393793  0.0  0.000000  0.000000
# zip                18858.0  0.415261  0.492780  0.0  0.000000  0.000000
#
#                         75%  max
# sqft_above         0.764159  1.0
# sqft_lot15         0.591237  1.0
# sqft_living15      0.731271  1.0
# waterfront         0.000000  1.0
# view               0.000000  1.0
# condition          0.882380  1.0
# grade              0.732285  1.0
# bedrooms           0.240661  1.0
# sqft_basement_cat  0.902657  1.0
# floors             0.720852  1.0
# yr_built_cat       0.000000  1.0
# zip                1.000000  1.0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state = 1)

# We need to cast again into df to visualize the decision tree
X_train_df = pd.DataFrame(X_train, columns=X.columns)
#y_train_df = pd.DataFrame(y_train, columns=["Price"])

X_test_df = pd.DataFrame(X_test, columns=X.columns)
#y_test_df = pd.DataFrame(y_test, columns=["Price"])

# %%
X_train_df
# Out:
#        sqft_above  sqft_lot15  sqft_living15  waterfront      view  condition  \
# 13298    0.708649    0.787260       0.716268         0.0  0.000000   1.000000
# 5444     0.549340    0.619603       0.606093         0.0  0.000000   1.000000
# 7336     0.841922    0.695841       0.862578         0.0  0.999991   0.716436
# 11475    0.659271    0.495419       0.784940         0.0  0.999885   0.882380
# 368      0.637493    0.144312       0.512960         0.0  0.000000   0.882380
# ...           ...         ...            ...         ...       ...        ...
# 10955    0.466509    0.450128       0.426829         0.0  0.000000   0.882380
# 17289    0.626103    0.335247       0.512960         0.0  0.000000   0.460479
# 5192     0.626103    0.569159       0.516726         0.0  0.000000   0.460479
# 12172    0.771982    0.470458       0.695542         0.0  0.000000   0.716436
# 235      0.516000    0.441155       0.355315         0.0  0.000000   0.716436
#
#           grade  bedrooms  sqft_basement_cat    floors  yr_built_cat  zip
# 13298  0.647530  0.240661           0.902657  0.000000           0.0  1.0
# 5444   0.863063  0.240661           1.000000  0.000000           0.0  0.0
# 7336   0.863063  0.240661           1.000000  0.720852           0.0  1.0
# 11475  0.647530  0.176175           0.902657  0.000000           0.0  1.0
# 368    0.732285  0.240661           0.902657  0.000000           0.0  0.0
# ...         ...       ...                ...       ...           ...  ...
# 10955  0.732285  0.176175           1.000000  0.000000           0.0  0.0
# 17289  0.647530  0.176175           0.000000  0.000000           0.0  1.0
# 5192   0.732285  0.176175           0.680998  0.000000           0.0  0.0
# 12172  0.732285  0.176175           0.902657  0.720852           0.0  0.0
# 235    0.863063  0.296463           0.000000  0.720852           0.0  0.0
#
# [14143 rows x 12 columns]

# %% [markdown]
# we will fit a decision tree, we will use a crossvalidation to explore the best fitting model

# %%
regr = DecisionTreeRegressor(max_depth=5,
                             criterion = 'squared_error',
                             min_samples_split=2,
                             min_samples_leaf = 1,
                             max_features = 6)

# %%
from sklearn.model_selection import cross_validate


results = cross_validate(regr, X_train, y_train, cv = 5)
results
# Out:
# {'fit_time': array([0.03097773, 0.01799798, 0.02298474, 0.01898766, 0.01799154]),
#  'score_time': array([0.0039947 , 0.00199103, 0.00199914, 0.00199938, 0.00200129]),
#  'test_score': array([0.49198896, 0.54540173, 0.53429989, 0.564684  , 0.54103062])}

# %%
#get average of testscore
print(results['test_score'])
print("The average R2 over the folds is: {:.2f}".format(results['test_score'].mean()))
# Out:
# [0.49198896 0.54540173 0.53429989 0.564684   0.54103062]
# The average R2 over the folds is: 0.54

# %% [markdown]
# it´s almost the same as the value we got in linear regression.

# %% [markdown]
# let´s use grid search to find a better performance

# %%
from sklearn.model_selection import GridSearchCV

max_depth_choices = [3,5] # max_depth lists to try
criterion_choices = ['squared_error','absolute_error'] # possible values optimization metrics list
min_samples_split_choices = [2,10] # list of possible values of min_samples_split to try
min_samples_leaf_choices = [2,10] # list of the possible values of min_samples_leaf to try

# %%
#create grid, which is a dictionary with hyperparameters
grid = {'max_depth': max_depth_choices,
        'criterion': criterion_choices,
        'min_samples_split': min_samples_split_choices,
        'min_samples_leaf': min_samples_leaf_choices}

# %%
model = DecisionTreeRegressor()
grid_search = GridSearchCV(estimator = model, param_grid = grid, cv = 5)

# %%
#fit
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_depth': [3, 5], 'min_samples_leaf': [2, 10],
#                          'min_samples_split': [2, 10]})

# %%
#best r2
print("The best R2 for the best hyperparameters is {:.2f}".format(grid_search.best_score_))
# Out:
# The best R2 for the best hyperparameters is 0.58

# %%
print("The performace of the DecisionTree using the best gridsearchcv hyperpameters is {:.2f}".format(grid_search.best_estimator_.score(X_test, y_test)))
# Out:
# The performace of the DecisionTree using the best gridsearchcv hyperpameters is 0.59

# %%
#see the best parameter
grid_search.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 5,
#  'min_samples_leaf': 2,
#  'min_samples_split': 10}

# %% [markdown]
# check random search

# %%
import numpy as np

# %%
from sklearn.model_selection import RandomizedSearchCV

max_depth_choices= np.random.randint(low=1, high=len(X.columns), size=3) # A random integer between 1 and the number of columns
criterion_choices =  ['squared_error','absolute_error'] # A list of the possible values optimization metrics
min_samples_split_choices = np.random.randint(low=2, high=10, size=3) # A random integer between 1 and the number of columns
min_samples_leaf_choices = np.random.randint(low=2, high=10, size=3) # A random integer between 1 and the number of columns
max_features_choices = np.random.randint(low=1, high=len(X.columns), size=3) # A random integer between 1 and the number of columns

random_grid = {'max_depth': max_depth_choices,
               'criterion': criterion_choices,
               'min_samples_split': min_samples_split_choices,
               'min_samples_leaf': min_samples_leaf_choices,
               'max_features': max_features_choices}

# %%
model = DecisionTreeRegressor()
# n_iter is how many random combinations of hyperparameters will test use the computer.
random_search = RandomizedSearchCV(estimator = model, param_distributions = random_grid, n_iter=25, cv = 5, n_jobs = 2)

# %%
random_search.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(), n_iter=25, n_jobs=2,
#                    param_distributions={'criterion': ['squared_error',
#                                                       'absolute_error'],
#                                         'max_depth': array([7, 5, 1]),
#                                         'max_features': array([8, 7, 5]),
#                                         'min_samples_leaf': array([9, 2, 3]),
#                                         'min_samples_split': array([4, 2, 5])})

# %%
random_search.best_params_
# Out:
# {'min_samples_split': 2,
#  'min_samples_leaf': 9,
#  'max_features': 8,
#  'max_depth': 7,
#  'criterion': 'squared_error'}

# %%
print("The best R2 according to the random search is {:.2f}".format(random_search.best_score_))
# Out:
# The best R2 according to the random search is 0.59

# %%
#let´s use this model
model = DecisionTreeRegressor (min_samples_split= 10,
                               min_samples_leaf= 8,
                               max_features= 8,
                               max_depth= 9,
                               criterion= 'squared_error')

# %%
model.fit(X_train, y_train)
model.score(X_test, y_test).round(2)
# Out:
# 0.61

# %% [markdown]
# so far it had produced the best R2 score at 0.63 for the test data, a litle above the score from randomized search . and for train set
# :

# %%
model.score(X_train, y_train).round(2)
# Out:
# 0.69

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
y_train_pred = [round(value, 2) for value in y_train_pred]
y_test_pred= [round(value, 2) for value in y_test_pred]

# Create a dictionary with the results
results = {
    "Set": ["Train"] * len(X_train) + ["Test"] * len(X_test),
    "Real": list(y_train) + list(y_test),
    "Predicted": y_train_pred + y_test_pred
}

# Create the results DataFrame
results_df = pd.DataFrame(results)
results_df
# Out:
#          Set     Real   Predicted
# 0      Train   527950   539034.00
# 1      Train  2850000  1354250.00
# 2      Train  1540000  1490954.55
# 3      Train   339000   499774.71
# 4      Train   785000   512014.45
# ...      ...      ...         ...
# 18853   Test   437500   371799.33
# 18854   Test   485000   512014.45
# 18855   Test   593000  1095125.00
# 18856   Test   310000   445398.71
# 18857   Test   385000   476755.11
#
# [18858 rows x 3 columns]

# %%
results_df.columns
# Out:
# Index(['Set', 'Real', 'Predicted'], dtype='object')

# %%
results_df['Errors'] = results_df['Real'] - results_df['Predicted']
results_df.head()
# Out:
#      Set     Real   Predicted      Errors
# 0  Train   527950   539034.00   -11084.00
# 1  Train  2850000  1354250.00  1495750.00
# 2  Train  1540000  1490954.55    49045.45
# 3  Train   339000   499774.71  -160774.71
# 4  Train   785000   512014.45   272985.55

# %%
results_df.shape
# Out:
# (18858, 4)

# %%
#select only rows where real is greater than 1000000
results_df2 = results_df[results_df['Real'] > 1000000]
results_df2.head()
# Out:
#       Set     Real   Predicted      Errors
# 1   Train  2850000  1354250.00  1495750.00
# 2   Train  1540000  1490954.55    49045.45
# 21  Train  2200000  2095833.33   104166.67
# 28  Train  1160000   849033.96   310966.04
# 35  Train  1350000  1477291.67  -127291.67

# %%
#visualize real and predicted
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

fig, ax = plt.subplots(1,2, figsize=(10,5))

sns.scatterplot(data=results_df, x="Real", y="Predicted", hue="Set", ax=ax[0])
sns.lineplot(data=results_df, x="Real", y="Real", color="black", ax=ax[0])
ax[0].set_title("Predicted vs real")
sns.histplot(results_df, x="Errors", bins=50, hue="Set", ax=ax[1])
ax[1].set_title("Histogram of residuals")

plt.tight_layout()
plt.show()

# %%
#test for mae, mse, rmse, r2
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
def error_metrics_report(y_real_train: list, y_real_test: list, y_pred_train: list, y_pred_test: list) -> pd.DataFrame:
    '''
   The error metrics report function calculates for regression.

    Parameters:
    - y_real_train (list): The actual target values for the training dataset.
    - y_real_test (list): The actual target values for the testing dataset.
    - y_pred_train (list): The predicted target values for the training dataset.
    - y_pred_test (list): The predicted target values for the testing dataset.

    Returns:
    - metrics_df (DataFrame): A Pandas DataFrame containing error metrics for both the training and testing datasets.
    - 'Metric' (str): The name of the error metric.
    - 'Training Set' (float): The error metric value for the training set.
    - 'Testing Set' (float): The error metric value for the testing set.
    '''

    MAE_train = mean_absolute_error(y_real_train, y_pred_train)
    MAE_test  = mean_absolute_error(y_real_test, y_pred_test)

    # Mean squared error
    MSE_train = mean_squared_error(y_real_train, y_pred_train)
    MSE_test  = mean_squared_error(y_real_test, y_pred_test)

    # Root mean squared error
    RMSE_train = mean_squared_error(y_real_train, y_pred_train)
    RMSE_test  = mean_squared_error(y_real_test, y_pred_test)

    # R2
    R2_train = r2_score(y_real_train, y_pred_train)
    R2_test  = r2_score(y_real_test, y_pred_test)

    results = {"Metric":['MAE', 'MSE', 'RMSE', 'R2'] , 
               "Train": [MAE_train, MSE_train, RMSE_train, R2_train],
               "Test":  [MAE_test, MSE_test, RMSE_test, R2_test]}

    results_df = pd.DataFrame(results).round(2)

    pd.set_option('display.float_format', lambda x: '{:.2f}'.format(x))


    return results_df

# %%
error_metrics_report(list(results_df[results_df["Set"]=="Train"]["Real"]),
                     list(results_df[results_df["Set"]=="Test"]["Real"]),
                     list(results_df[results_df["Set"]=="Train"]["Predicted"]),
                     list(results_df[results_df["Set"]=="Test"]["Predicted"]))
# Out:
#   Metric          Train           Test
# 0    MAE      133942.91      143584.29
# 1    MSE 42347939174.47 51185063391.17
# 2   RMSE 42347939174.47 51185063391.17
# 3     R2           0.69           0.61
