# %%
import pandas as pd

# %%
#read excel file
file_path = '../data/raw/regression_data.xls'
#read excel file
df = pd.read_excel(file_path)

# %%
df.head()
# Out:
#            id       date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520 2014-10-13         3       1.00         1180      5650     1.0
# 1  6414100192 2014-12-09         3       2.25         2570      7242     2.0
# 2  5631500400 2015-02-25         2       1.00          770     10000     1.0
# 3  2487200875 2014-12-09         4       3.00         1960      5000     1.0
# 4  1954400510 2015-02-18         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
# ...

# %%
df.shape
# Out:
# (21597, 21)

# %%
df.columns
# Out:
# Index(['id', 'date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'price'],
#       dtype='object')

# %%
#add a column labels and convert the current column lable to first row
#df.columns = df.iloc[0]
df.head()
# Out:
#            id       date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520 2014-10-13         3       1.00         1180      5650     1.0
# 1  6414100192 2014-12-09         3       2.25         2570      7242     2.0
# 2  5631500400 2015-02-25         2       1.00          770     10000     1.0
# 3  2487200875 2014-12-09         4       3.00         1960      5000     1.0
# 4  1954400510 2015-02-18         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
# ...

# %%
#check data types
df.dtypes
# Out:
# id                        int64
# date             datetime64[ns]
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# price                     int64
# dtype: object

# %%
#check missing values
df.isnull().sum()

# %%
#do a value count for each column
for col in df.columns:
    print(df[col].value_counts())
# Out:
# id
# 795000620     3
# 8910500150    2
# 7409700215    2
# 1995200200    2
# 9211500620    2
#              ..
# 3649100387    1
# 2767603649    1
# 1446403617    1
# 5602000275    1
# 1523300157    1
# Name: count, Length: 21420, dtype: int64
# date
# 2014-06-23    142
# 2014-06-25    131
# 2014-06-26    131
# 2014-07-08    127
# 2015-04-27    126
#              ...
# 2014-11-02      1
# 2015-01-31      1
# 2015-05-24      1
# 2014-05-17      1
# 2014-07-27      1
# Name: count, Length: 372, dtype: int64
# bedrooms
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      196
# 7       38
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: count, dtype: int64
# bathrooms
# 2.50    5377
# 1.00    3851
# 1.75    3048
# 2.25    2047
# 2.00    1930
# 1.50    1445
# 2.75    1185
# 3.00     753
# 3.50     731
# 3.25     589
# 3.75     155
# 4.00     136
# 4.50     100
# 4.25      79
# 0.75      71
# 4.75      23
# 5.00      21
# 5.25      13
# ...

# %%
#on date column, check the year range
display(df['date'].min())
display(df['date'].max())
# Out:
# Timestamp('2014-05-02 00:00:00')
# Timestamp('2015-05-27 00:00:00')

# %% [markdown]
# Date : Defined as the date the house was sold. We understand that the date a house was sold affects price of property, but our database is between a year. A lot can happen in year with regard to real estate bubble , but typically a real estate bubble happens less frequently compared to stockmarket busts and lasts as much as 8 years Housing price busts are less frequent (IMF World Economic Outlook, 2003)
# see in link(https://en.wikipedia.org/wiki/Real-estate_bubble#cite_ref-2.).
# As a result we will disregard the date ,due to high uncertainty.

# %%
#drop date column
df = df.drop('date', axis=1)

# %% [markdown]
# ## DATA CATEGORIES
#
# Our dataframe contains both numerical and categorical data. The categorical columns are already encoded , meaning we focus our attention on addressing our numerical data now.
#
# We will check for skewness and others

# %%
#see data columns
df.columns
# Out:
# Index(['id', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'price'],
#       dtype='object')

# %% [markdown]
# our numerical datas are
# 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_above', 'sqft_lot', 'floors',sqft_lot15,'sqft_living15', price
#
# categorical data are
# waterfront, view, condition, grade,yr_built , yr_renovated, zipcode, 'lat', 'long',
#
# We will drop lat and long , as that will be compensated by zipcode
#
# for categorical data, we might consider splitting into ordinal and nominal
# :waterfront, view, condition, yr_built, yr_renovated
#
# zip_code is nominal

# %%
#check value in sqft_living15 column
df['sqft_living'].value_counts()
# Out:
# sqft_living
# 1300    138
# 1400    135
# 1440    133
# 1800    129
# 1660    129
#        ...
# 2507      1
# 9890      1
# 5584      1
# 1961      1
# 1425      1
# Name: count, Length: 1034, dtype: int64

# %% [markdown]
# ## size data
#
# since the square size for livingroom and lot were updated after many reconstruction in 2015, we will not use the old livingroom and lotsize

# %%
#drop sqft_living, sqft_lot,  column, long and lat
df = df.drop(['sqft_living', 'sqft_lot', 'long', 'lat'], axis=1)

df.head()
# Out:
#            id  bedrooms  bathrooms  floors  waterfront  view  condition  \
# 0  7129300520         3       1.00     1.0           0     0          3
# 1  6414100192         3       2.25     2.0           0     0          3
# 2  5631500400         2       1.00     1.0           0     0          3
# 3  2487200875         4       3.00     1.0           0     0          5
# 4  1954400510         3       2.00     1.0           0     0          3
#
#    grade  sqft_above  sqft_basement  yr_built  yr_renovated  zipcode  \
# 0      7        1180              0      1955             0    98178
# 1      7        2170            400      1951          1991    98125
# 2      6         770              0      1933             0    98028
# 3      7        1050            910      1965             0    98136
# 4      8        1680              0      1987             0    98074
#
#    sqft_living15  sqft_lot15   price
# 0           1340        5650  221900
# 1           1690        7639  538000
# ...

# %% [markdown]
# #customer_id is totally useless to this operation, it might as well be replaced by index

# %%
#drop id column
df = df.drop('id', axis=1)

# %%
df.head()
# Out:
#    bedrooms  bathrooms  floors  waterfront  view  condition  grade  \
# 0         3       1.00     1.0           0     0          3      7
# 1         3       2.25     2.0           0     0          3      7
# 2         2       1.00     1.0           0     0          3      6
# 3         4       3.00     1.0           0     0          5      7
# 4         3       2.00     1.0           0     0          3      8
#
#    sqft_above  sqft_basement  yr_built  yr_renovated  zipcode  sqft_living15  \
# 0        1180              0      1955             0    98178           1340
# 1        2170            400      1951          1991    98125           1690
# 2         770              0      1933             0    98028           2720
# 3        1050            910      1965             0    98136           1360
# 4        1680              0      1987             0    98074           1800
#
#    sqft_lot15   price
# 0        5650  221900
# 1        7639  538000
# 2        8062  180000
# ...

# %%
#save the cleaned data to a new file
df.to_csv('../data/raw/first_clean.csv', index=False)
